# %%
import re

# %%
chat1='Say: Here is the issue with my order # 412889912'

pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat1)
matches
# Out:
# ['412889912']

# %%
chat2='Say: Here is the issue with my order # 412889912'

pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat2)
matches
# Out:
# ['412889912']

# %%
chat3='Say: Here is the issue with my order # 412889912'

pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat3)
matches
# Out:
# ['412889912']

# %%
chat1='Say: you ask lot of question 1235678912, abc@xyz.com'
chat2='Say: here it is: (123)-567-8912, abc@xyz.com'
chat3='Say: Hello, phone: 1235678912 email: abc@xyz.com'

# %%
pattern = '\d{10}|\(\d{3}\)-\d{3}-\d{4}'

matches = re.findall(pattern, chat1)
matches
# Out:
# ['1235678912']

# %%
pattern = '[a-z0-9A-Z]*@[a-z0-9A-Z]*\.[a-zA-Z]*'

matches = re.findall(pattern, chat3)
email=matches[0]
email
# Out:
# 'abc@xyz.com'

# %%
chat1='Say: Hello, I am having an issue with my order # 412889912'
chat2='Say: I have a problem with my order number 412889912'
chat3='Say: My order 412889912 is having an issue, I was charged 300$ when online it says 280$'

# %%
pattern = 'order[^\d]*(\d*)'
matches = re.findall(pattern, chat2)
matches
# Out:
# ['412889912']

# %% [markdown]
# Information Extraction

# %%
text='''
Born	Elon Reeve Musk
June 28, 1971 (age 50)
Pretoria, Transvaal, South Africa
Citizenship	
South Africa (1971–present)
Canada (1971–present)
United States (2002–present)
Education	University of Pennsylvania (BS, BA)
Title	
Founder, CEO and Chief Engineer of SpaceX
CEO and product architect of Tesla, Inc.
Founder of The Boring Company and X.com (now part of PayPal)
Co-founder of Neuralink, OpenAI, and Zip2
Spouse(s)	
Justine Wilson
​
​(m. 2000; div. 2008)​
Talulah Riley
​
​(m. 2010; div. 2012)​
​
​(m. 2013; div. 2016)
'''

# %%
pattern='age (\d+)'
matches = re.findall(pattern, text)
matches
# Out:
# ['50']

# %%
pattern='Born(.*)'
matches = re.findall(pattern, text)
matches[0].strip()
# Out:
# 'Elon Reeve Musk'

# %%
pattern='Born.*\n(.*)\(age'
matches = re.findall(pattern, text)
matches[0].strip()
# Out:
# 'June 28, 1971'

# %%
pattern='\(age.*\n(.*)'
matches = re.findall(pattern, text)
matches[0].strip()
# Out:
# 'Pretoria, Transvaal, South Africa'

# %%
def get_pattern_match(pattern, text):
    matches=re.findall(pattern, text)
    if matches:
        return matches[0]

# %%
get_pattern_match('\(age.*\n(.*)', text)
# Out:
# 'Pretoria, Transvaal, South Africa'

# %%
def get_personal_information(text):
    age = get_pattern_match('age (\d+)', text)
    full_name = get_pattern_match('Born(.*)\n', text)
    birth_date = get_pattern_match('Born.*\n(.*)\(age', text)
    birth_place = get_pattern_match('\(age.*\n(.*)', text)
    return {
        'age': int(age),
        'name': full_name.strip(),
        'birth_date': birth_date.strip(),
        'birth_place': birth_place.strip()
    }

# %%
get_personal_information(text)
# Out:
# {'age': 50,
#  'name': 'Elon Reeve Musk',
#  'birth_date': 'June 28, 1971',
#  'birth_place': 'Pretoria, Transvaal, South Africa'}
